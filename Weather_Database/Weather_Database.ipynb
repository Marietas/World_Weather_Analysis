# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 748

# %%
import requests
requests.__version__
# Out:
# '2.24.0'

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e7eca9fd43ae0eecc49dd2c79c89d6ee

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pisco
# Processing Record 2 of Set 1 | vila franca do campo
# Processing Record 3 of Set 1 | purpe
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | ponta do sol
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | paamiut
# Processing Record 13 of Set 1 | bambanglipuro
# Processing Record 14 of Set 1 | saint george
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | talcahuano
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | nigde
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | korla
# Processing Record 21 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 1 | chicama
# Processing Record 23 of Set 1 | izhma
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | nelson bay
# Processing Record 26 of Set 1 | coihaique
# Processing Record 27 of Set 1 | karak
# Processing Record 28 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 1 | sitka
# Processing Record 30 of Set 1 | sinnamary
# Processing Record 31 of Set 1 | saint anthony
# Processing Record 32 of Set 1 | laguna
# Processing Record 33 of Set 1 | yellowknife
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | berlevag
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | nome
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 1 | opuwo
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | beringovskiy
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | yar-sale
# Processing Record 46 of Set 1 | longyearbyen
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | raudeberg
# Processing Record 50 of Set 1 | bilma
# Processing Record 1 of Set 2 | esperance
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | acapulco
# Processing Record 4 of Set 2 | acajutla
# Processing Record 5 of Set 2 | bengkulu
# Processing Record 6 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | bambous virieux
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | mount gambier
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | marzuq
# Processing Record 13 of Set 2 | sarkand
# Processing Record 14 of Set 2 | tiquicheo
# Processing Record 15 of Set 2 | plyussa
# Processing Record 16 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 2 | bardejov
# Processing Record 18 of Set 2 | charters towers
# Processing Record 19 of Set 2 | eenhana
# Processing Record 20 of Set 2 | new norfolk
# Processing Record 21 of Set 2 | namatanai
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | fortuna
# Processing Record 24 of Set 2 | turukhansk
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | saskylakh
# Processing Record 30 of Set 2 | inhambane
# Processing Record 31 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 2 | san patricio
# Processing Record 33 of Set 2 | timmins
# Processing Record 34 of Set 2 | wilmington
# Processing Record 35 of Set 2 | pho thong
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 2 | atar
# Processing Record 40 of Set 2 | makasar
# Processing Record 41 of Set 2 | camapua
# Processing Record 42 of Set 2 | qasigiannguit
# Processing Record 43 of Set 2 | maple creek
# Processing Record 44 of Set 2 | ippy
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | zorritos
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 2 | bougouni
# Processing Record 50 of Set 2 | khatanga
# Processing Record 1 of Set 3 | kathu
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | phanom sarakham
# Processing Record 4 of Set 3 | camocim
# Processing Record 5 of Set 3 | severnyy
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | rocha
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | aklavik
# Processing Record 10 of Set 3 | tasiilaq
# Processing Record 11 of Set 3 | lorengau
# Processing Record 12 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 3 | tezpur
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | ribeira grande
# Processing Record 16 of Set 3 | tevaitoa
# Processing Record 17 of Set 3 | champerico
# Processing Record 18 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | roshchino
# Processing Record 20 of Set 3 | mayo
# Processing Record 21 of Set 3 | lexington
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | samana
# Processing Record 24 of Set 3 | ibitinga
# Processing Record 25 of Set 3 | constitucion
# Processing Record 26 of Set 3 | olafsvik
# Processing Record 27 of Set 3 | leningradskiy
# Processing Record 28 of Set 3 | koster
# Processing Record 29 of Set 3 | jaciara
# Processing Record 30 of Set 3 | bukene
# Processing Record 31 of Set 3 | hobart
# Processing Record 32 of Set 3 | bonavista
# Processing Record 33 of Set 3 | saint-denis
# Processing Record 34 of Set 3 | tiksi
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | souillac
# Processing Record 37 of Set 3 | margate
# Processing Record 38 of Set 3 | batagay
# Processing Record 39 of Set 3 | kudahuvadhoo
# Processing Record 40 of Set 3 | faanui
# Processing Record 41 of Set 3 | kapit
# Processing Record 42 of Set 3 | katsuura
# Processing Record 43 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | viedma
# Processing Record 46 of Set 3 | jerusalem
# Processing Record 47 of Set 3 | bubaque
# Processing Record 48 of Set 3 | wanaka
# Processing Record 49 of Set 3 | rio gallegos
# Processing Record 50 of Set 3 | kununurra
# Processing Record 1 of Set 4 | planaltina
# Processing Record 2 of Set 4 | tuatapere
# Processing Record 3 of Set 4 | aleksandrov gay
# Processing Record 4 of Set 4 | volchansk
# Processing Record 5 of Set 4 | energetik
# Processing Record 6 of Set 4 | bella vista
# Processing Record 7 of Set 4 | plettenberg bay
# Processing Record 8 of Set 4 | strezhevoy
# Processing Record 9 of Set 4 | hamilton
# Processing Record 10 of Set 4 | tuktoyaktuk
# Processing Record 11 of Set 4 | panama city
# Processing Record 12 of Set 4 | port-gentil
# Processing Record 13 of Set 4 | gao
# Processing Record 14 of Set 4 | lixourion
# Processing Record 15 of Set 4 | sobolevo
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | santa cruz del sur
# Processing Record 18 of Set 4 | palmer
# Processing Record 19 of Set 4 | lady lake
# Processing Record 20 of Set 4 | chulman
# Processing Record 21 of Set 4 | itupiranga
# Processing Record 22 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 4 | aleppo
# Processing Record 24 of Set 4 | monrovia
# Processing Record 25 of Set 4 | rognan
# Processing Record 26 of Set 4 | presidencia roque saenz pena
# Processing Record 27 of Set 4 | hami
# Processing Record 28 of Set 4 | koumac
# Processing Record 29 of Set 4 | beloha
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | blackwater
# Processing Record 32 of Set 4 | cidreira
# Processing Record 33 of Set 4 | morant bay
# Processing Record 34 of Set 4 | namtsy
# Processing Record 35 of Set 4 | nantucket
# Processing Record 36 of Set 4 | kodiak
# Processing Record 37 of Set 4 | barrow
# Processing Record 38 of Set 4 | mogochin
# City not found. Skipping...
# Processing Record 39 of Set 4 | borgarnes
# Processing Record 40 of Set 4 | xichang
# Processing Record 41 of Set 4 | warmbad
# Processing Record 42 of Set 4 | te anau
# Processing Record 43 of Set 4 | gander
# Processing Record 44 of Set 4 | cabadiangan
# Processing Record 45 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 4 | mantua
# Processing Record 47 of Set 4 | nanpara
# Processing Record 48 of Set 4 | murgab
# Processing Record 49 of Set 4 | talnakh
# Processing Record 50 of Set 4 | ilinge
# Processing Record 1 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 5 | bud
# Processing Record 3 of Set 5 | antsohihy
# Processing Record 4 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | alekseyevka
# Processing Record 7 of Set 5 | mananara
# Processing Record 8 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 5 | mizan teferi
# Processing Record 10 of Set 5 | houma
# Processing Record 11 of Set 5 | port elizabeth
# Processing Record 12 of Set 5 | port keats
# Processing Record 13 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 14 of Set 5 | angra dos reis
# Processing Record 15 of Set 5 | quatre cocos
# Processing Record 16 of Set 5 | guerrero negro
# Processing Record 17 of Set 5 | sampit
# Processing Record 18 of Set 5 | kurilsk
# Processing Record 19 of Set 5 | aloleng
# Processing Record 20 of Set 5 | iskateley
# Processing Record 21 of Set 5 | peru
# Processing Record 22 of Set 5 | pangoa
# Processing Record 23 of Set 5 | chake chake
# Processing Record 24 of Set 5 | eskhar
# Processing Record 25 of Set 5 | bathsheba
# Processing Record 26 of Set 5 | ahipara
# Processing Record 27 of Set 5 | carnarvon
# Processing Record 28 of Set 5 | tautira
# Processing Record 29 of Set 5 | chokurdakh
# Processing Record 30 of Set 5 | yuli
# Processing Record 31 of Set 5 | sao sebastiao
# Processing Record 32 of Set 5 | port hedland
# Processing Record 33 of Set 5 | sioux lookout
# Processing Record 34 of Set 5 | ranong
# Processing Record 35 of Set 5 | adrar
# Processing Record 36 of Set 5 | kailua
# Processing Record 37 of Set 5 | broken hill
# Processing Record 38 of Set 5 | high rock
# Processing Record 39 of Set 5 | kalabo
# Processing Record 40 of Set 5 | ancud
# Processing Record 41 of Set 5 | marawi
# Processing Record 42 of Set 5 | ostrovnoy
# Processing Record 43 of Set 5 | lewiston
# Processing Record 44 of Set 5 | coquimbo
# Processing Record 45 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 5 | port alfred
# Processing Record 47 of Set 5 | tambopata
# Processing Record 48 of Set 5 | mugur-aksy
# Processing Record 49 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 5 | namibe
# Processing Record 1 of Set 6 | lavrentiya
# Processing Record 2 of Set 6 | clyde river
# Processing Record 3 of Set 6 | dingle
# Processing Record 4 of Set 6 | cayenne
# Processing Record 5 of Set 6 | vao
# Processing Record 6 of Set 6 | tura
# Processing Record 7 of Set 6 | vestmannaeyjar
# Processing Record 8 of Set 6 | nacala
# Processing Record 9 of Set 6 | anito
# Processing Record 10 of Set 6 | dalvik
# Processing Record 11 of Set 6 | la rioja
# Processing Record 12 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 13 of Set 6 | ningan
# City not found. Skipping...
# Processing Record 14 of Set 6 | kirakira
# Processing Record 15 of Set 6 | sao felix do xingu
# Processing Record 16 of Set 6 | batemans bay
# Processing Record 17 of Set 6 | shibetsu
# Processing Record 18 of Set 6 | pevek
# Processing Record 19 of Set 6 | yeppoon
# Processing Record 20 of Set 6 | guadalajara
# Processing Record 21 of Set 6 | port lincoln
# Processing Record 22 of Set 6 | tigil
# Processing Record 23 of Set 6 | sao jose da coroa grande
# Processing Record 24 of Set 6 | wewak
# Processing Record 25 of Set 6 | lluta
# Processing Record 26 of Set 6 | rocky mountain house
# Processing Record 27 of Set 6 | lagunillas
# Processing Record 28 of Set 6 | palmas bellas
# Processing Record 29 of Set 6 | wajima
# Processing Record 30 of Set 6 | honningsvag
# Processing Record 31 of Set 6 | saint-philippe
# Processing Record 32 of Set 6 | san quintin
# Processing Record 33 of Set 6 | roebourne
# Processing Record 34 of Set 6 | simao
# Processing Record 35 of Set 6 | yankton
# Processing Record 36 of Set 6 | lahat
# Processing Record 37 of Set 6 | semirom
# Processing Record 38 of Set 6 | provideniya
# Processing Record 39 of Set 6 | ishigaki
# Processing Record 40 of Set 6 | boyolangu
# Processing Record 41 of Set 6 | ransang
# Processing Record 42 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 6 | kampene
# Processing Record 44 of Set 6 | mikhaylovskoye
# Processing Record 45 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 46 of Set 6 | paracatu
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | ibra
# Processing Record 49 of Set 6 | provost
# Processing Record 50 of Set 6 | kavieng
# Processing Record 1 of Set 7 | magadan
# Processing Record 2 of Set 7 | bulgan
# Processing Record 3 of Set 7 | nanortalik
# Processing Record 4 of Set 7 | narsaq
# Processing Record 5 of Set 7 | pochutla
# Processing Record 6 of Set 7 | walvis bay
# Processing Record 7 of Set 7 | abonnema
# Processing Record 8 of Set 7 | qorveh
# Processing Record 9 of Set 7 | vilyuysk
# Processing Record 10 of Set 7 | russell
# Processing Record 11 of Set 7 | hay river
# Processing Record 12 of Set 7 | padang
# Processing Record 13 of Set 7 | acarau
# Processing Record 14 of Set 7 | klaksvik
# Processing Record 15 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 7 | cockburn town
# Processing Record 17 of Set 7 | torbay
# Processing Record 18 of Set 7 | meadow lake
# Processing Record 19 of Set 7 | reforma
# Processing Record 20 of Set 7 | roma
# Processing Record 21 of Set 7 | haapiti
# Processing Record 22 of Set 7 | porto de moz
# Processing Record 23 of Set 7 | yulara
# Processing Record 24 of Set 7 | riverton
# Processing Record 25 of Set 7 | chara
# Processing Record 26 of Set 7 | antibes
# Processing Record 27 of Set 7 | otjimbingwe
# Processing Record 28 of Set 7 | preobrazheniye
# Processing Record 29 of Set 7 | diamantino
# Processing Record 30 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 7 | bognor regis
# Processing Record 32 of Set 7 | jinan
# Processing Record 33 of Set 7 | lasa
# Processing Record 34 of Set 7 | dunedin
# Processing Record 35 of Set 7 | miraflores
# Processing Record 36 of Set 7 | kamenka
# Processing Record 37 of Set 7 | berndorf
# Processing Record 38 of Set 7 | tank
# Processing Record 39 of Set 7 | dombarovskiy
# Processing Record 40 of Set 7 | tateyama
# Processing Record 41 of Set 7 | radcliff
# Processing Record 42 of Set 7 | maryville
# Processing Record 43 of Set 7 | lovozero
# Processing Record 44 of Set 7 | nakusp
# Processing Record 45 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 46 of Set 7 | jinchang
# Processing Record 47 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 7 | fairbanks
# Processing Record 49 of Set 7 | udachnyy
# Processing Record 50 of Set 7 | touros
# Processing Record 1 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 8 | seoul
# Processing Record 3 of Set 8 | georgetown
# Processing Record 4 of Set 8 | nova olinda do norte
# Processing Record 5 of Set 8 | peniche
# Processing Record 6 of Set 8 | awbari
# Processing Record 7 of Set 8 | burica
# City not found. Skipping...
# Processing Record 8 of Set 8 | sur
# Processing Record 9 of Set 8 | clarence town
# Processing Record 10 of Set 8 | ziway
# Processing Record 11 of Set 8 | pangnirtung
# Processing Record 12 of Set 8 | ipameri
# Processing Record 13 of Set 8 | marsh harbour
# Processing Record 14 of Set 8 | manta
# Processing Record 15 of Set 8 | port hardy
# Processing Record 16 of Set 8 | nemuro
# Processing Record 17 of Set 8 | airai
# Processing Record 18 of Set 8 | shimoda
# Processing Record 19 of Set 8 | keffi
# Processing Record 20 of Set 8 | vostok
# Processing Record 21 of Set 8 | castro
# Processing Record 22 of Set 8 | havre-saint-pierre
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | mildura
# Processing Record 25 of Set 8 | mayumba
# Processing Record 26 of Set 8 | kushmurun
# Processing Record 27 of Set 8 | nuuk
# Processing Record 28 of Set 8 | narasannapeta
# Processing Record 29 of Set 8 | balkhash
# Processing Record 30 of Set 8 | lebu
# Processing Record 31 of Set 8 | novyy urengoy
# Processing Record 32 of Set 8 | deputatskiy
# Processing Record 33 of Set 8 | halifax
# Processing Record 34 of Set 8 | aksay
# Processing Record 35 of Set 8 | becal
# Processing Record 36 of Set 8 | vardo
# Processing Record 37 of Set 8 | hirara
# Processing Record 38 of Set 8 | puerto madero
# Processing Record 39 of Set 8 | naze
# Processing Record 40 of Set 8 | capitan bado
# Processing Record 41 of Set 8 | san andres
# Processing Record 42 of Set 8 | caravelas
# Processing Record 43 of Set 8 | monroe
# Processing Record 44 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 8 | bandarbeyla
# Processing Record 46 of Set 8 | flinders
# Processing Record 47 of Set 8 | grindavik
# Processing Record 48 of Set 8 | flin flon
# Processing Record 49 of Set 8 | saint-georges
# Processing Record 50 of Set 8 | salalah
# Processing Record 1 of Set 9 | rudbar
# Processing Record 2 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 3 of Set 9 | hailar
# Processing Record 4 of Set 9 | arani
# Processing Record 5 of Set 9 | taoudenni
# Processing Record 6 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 7 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 9 | fazilka
# Processing Record 9 of Set 9 | kirundo
# Processing Record 10 of Set 9 | matrei
# City not found. Skipping...
# Processing Record 11 of Set 9 | sorland
# Processing Record 12 of Set 9 | hofn
# Processing Record 13 of Set 9 | makubetsu
# Processing Record 14 of Set 9 | labuhan
# Processing Record 15 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 9 | moose factory
# Processing Record 17 of Set 9 | conde
# Processing Record 18 of Set 9 | komsomolets
# Processing Record 19 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 9 | stokmarknes
# Processing Record 21 of Set 9 | kenai
# Processing Record 22 of Set 9 | nicolas bravo
# Processing Record 23 of Set 9 | bichena
# Processing Record 24 of Set 9 | sambava
# Processing Record 25 of Set 9 | mnogovershinnyy
# Processing Record 26 of Set 9 | yeniseysk
# Processing Record 27 of Set 9 | barra velha
# Processing Record 28 of Set 9 | shubarkuduk
# Processing Record 29 of Set 9 | ngaoundere
# Processing Record 30 of Set 9 | camacha
# Processing Record 31 of Set 9 | adelaide
# Processing Record 32 of Set 9 | ouadda
# Processing Record 33 of Set 9 | lagoa
# Processing Record 34 of Set 9 | ixtapa
# Processing Record 35 of Set 9 | trairi
# Processing Record 36 of Set 9 | puqi
# Processing Record 37 of Set 9 | aragarcas
# Processing Record 38 of Set 9 | san policarpo
# Processing Record 39 of Set 9 | thompson
# Processing Record 40 of Set 9 | krasnoselkup
# Processing Record 41 of Set 9 | kapoeta
# Processing Record 42 of Set 9 | los llanos de aridane
# Processing Record 43 of Set 9 | lompoc
# Processing Record 44 of Set 9 | nambucca heads
# Processing Record 45 of Set 9 | dien bien
# City not found. Skipping...
# Processing Record 46 of Set 9 | pimenta bueno
# Processing Record 47 of Set 9 | bin qirdan
# Processing Record 48 of Set 9 | soe
# Processing Record 49 of Set 9 | mpika
# Processing Record 50 of Set 9 | vanderhoof
# Processing Record 1 of Set 10 | husavik
# Processing Record 2 of Set 10 | ak-dovurak
# Processing Record 3 of Set 10 | gat
# Processing Record 4 of Set 10 | le port
# Processing Record 5 of Set 10 | port blair
# Processing Record 6 of Set 10 | cherskiy
# Processing Record 7 of Set 10 | sabaudia
# Processing Record 8 of Set 10 | kieta
# Processing Record 9 of Set 10 | mitsamiouli
# Processing Record 10 of Set 10 | kahului
# Processing Record 11 of Set 10 | formosa
# Processing Record 12 of Set 10 | mangaluru
# Processing Record 13 of Set 10 | byron bay
# Processing Record 14 of Set 10 | henties bay
# Processing Record 15 of Set 10 | papara
# Processing Record 16 of Set 10 | mazagao
# Processing Record 17 of Set 10 | manggar
# Processing Record 18 of Set 10 | sakakah
# Processing Record 19 of Set 10 | knysna
# Processing Record 20 of Set 10 | balaipungut
# Processing Record 21 of Set 10 | eyl
# Processing Record 22 of Set 10 | san ignacio
# Processing Record 23 of Set 10 | bowen
# Processing Record 24 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 10 | khani
# Processing Record 26 of Set 10 | itarantim
# Processing Record 27 of Set 10 | myaundzha
# Processing Record 28 of Set 10 | carutapera
# Processing Record 29 of Set 10 | pacific grove
# Processing Record 30 of Set 10 | rudnichnyy
# Processing Record 31 of Set 10 | assiniboia
# Processing Record 32 of Set 10 | hambantota
# Processing Record 33 of Set 10 | porto novo
# Processing Record 34 of Set 10 | chimbote
# Processing Record 35 of Set 10 | lar gerd
# City not found. Skipping...
# Processing Record 36 of Set 10 | santa isabel do rio negro
# Processing Record 37 of Set 10 | yerbogachen
# Processing Record 38 of Set 10 | granadilla de abona
# Processing Record 39 of Set 10 | akdepe
# Processing Record 40 of Set 10 | saint-ambroise
# Processing Record 41 of Set 10 | saint-joseph
# Processing Record 42 of Set 10 | ketchikan
# Processing Record 43 of Set 10 | santa maria
# Processing Record 44 of Set 10 | kruisfontein
# Processing Record 45 of Set 10 | silifke
# Processing Record 46 of Set 10 | burdur
# Processing Record 47 of Set 10 | verkhnyaya inta
# Processing Record 48 of Set 10 | estelle
# Processing Record 49 of Set 10 | wattegama
# Processing Record 50 of Set 10 | poya
# Processing Record 1 of Set 11 | batagay-alyta
# Processing Record 2 of Set 11 | rozhdestveno
# Processing Record 3 of Set 11 | veraval
# Processing Record 4 of Set 11 | jacmel
# Processing Record 5 of Set 11 | trinidad
# Processing Record 6 of Set 11 | nouadhibou
# Processing Record 7 of Set 11 | turhal
# Processing Record 8 of Set 11 | arlit
# Processing Record 9 of Set 11 | morgan city
# Processing Record 10 of Set 11 | galeana
# Processing Record 11 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 12 of Set 11 | kambam
# Processing Record 13 of Set 11 | kerema
# Processing Record 14 of Set 11 | roald
# Processing Record 15 of Set 11 | dingli
# Processing Record 16 of Set 11 | duz
# City not found. Skipping...
# Processing Record 17 of Set 11 | mopipi
# Processing Record 18 of Set 11 | praia da vitoria
# Processing Record 19 of Set 11 | kargil
# Processing Record 20 of Set 11 | cravo norte
# Processing Record 21 of Set 11 | altay
# Processing Record 22 of Set 11 | berdigestyakh
# Processing Record 23 of Set 11 | miyako
# Processing Record 24 of Set 11 | sapao
# City not found. Skipping...
# Processing Record 25 of Set 11 | katherine
# Processing Record 26 of Set 11 | verkhnevilyuysk
# Processing Record 27 of Set 11 | norman wells
# Processing Record 28 of Set 11 | phimai
# Processing Record 29 of Set 11 | hongan
# City not found. Skipping...
# Processing Record 30 of Set 11 | seymchan
# Processing Record 31 of Set 11 | senno
# Processing Record 32 of Set 11 | ogbomosho
# Processing Record 33 of Set 11 | whitehorse
# Processing Record 34 of Set 11 | misratah
# Processing Record 35 of Set 11 | adamovka
# Processing Record 36 of Set 11 | sulphur
# Processing Record 37 of Set 11 | vibo valentia
# Processing Record 38 of Set 11 | ejido
# Processing Record 39 of Set 11 | pangody
# Processing Record 40 of Set 11 | karratha
# Processing Record 41 of Set 11 | nizhniy tsasuchey
# Processing Record 42 of Set 11 | olinda
# Processing Record 43 of Set 11 | kuraymah
# Processing Record 44 of Set 11 | fort nelson
# Processing Record 45 of Set 11 | abai
# Processing Record 46 of Set 11 | araripe
# Processing Record 47 of Set 11 | sao joao da barra
# Processing Record 48 of Set 11 | lieksa
# Processing Record 49 of Set 11 | fairfield
# Processing Record 50 of Set 11 | poso
# Processing Record 1 of Set 12 | richards bay
# Processing Record 2 of Set 12 | ucluelet
# Processing Record 3 of Set 12 | san carlos de bariloche
# Processing Record 4 of Set 12 | fare
# Processing Record 5 of Set 12 | riyadh
# Processing Record 6 of Set 12 | kingaroy
# Processing Record 7 of Set 12 | falam
# Processing Record 8 of Set 12 | nordhausen
# Processing Record 9 of Set 12 | biak
# Processing Record 10 of Set 12 | san carlos
# Processing Record 11 of Set 12 | nizwa
# Processing Record 12 of Set 12 | yondo
# Processing Record 13 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 12 | lincoln
# Processing Record 15 of Set 12 | ramotswa
# Processing Record 16 of Set 12 | kungurtug
# Processing Record 17 of Set 12 | kawalu
# Processing Record 18 of Set 12 | artvin
# Processing Record 19 of Set 12 | shihezi
# Processing Record 20 of Set 12 | krasnogorskoye
# Processing Record 21 of Set 12 | cessnock
# Processing Record 22 of Set 12 | oum hadjer
# Processing Record 23 of Set 12 | champawat
# Processing Record 24 of Set 12 | alexandria
# Processing Record 25 of Set 12 | muskogee
# Processing Record 26 of Set 12 | sawtell
# Processing Record 27 of Set 12 | aksarka
# Processing Record 28 of Set 12 | aswan
# Processing Record 29 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 30 of Set 12 | gari
# Processing Record 31 of Set 12 | smithers
# Processing Record 32 of Set 12 | louros
# Processing Record 33 of Set 12 | alyangula
# Processing Record 34 of Set 12 | okhotsk
# Processing Record 35 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 12 | liku
# Processing Record 37 of Set 12 | bogande
# Processing Record 38 of Set 12 | ballina
# Processing Record 39 of Set 12 | portree
# Processing Record 40 of Set 12 | balagansk
# Processing Record 41 of Set 12 | mbarara
# Processing Record 42 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 43 of Set 12 | borama
# City not found. Skipping...
# Processing Record 44 of Set 12 | panjab
# Processing Record 45 of Set 12 | orsha
# Processing Record 46 of Set 12 | abrau-dyurso
# Processing Record 47 of Set 12 | daru
# Processing Record 48 of Set 12 | kudinovo
# Processing Record 49 of Set 12 | srednekolymsk
# Processing Record 50 of Set 12 | portland
# Processing Record 1 of Set 13 | garbolovo
# Processing Record 2 of Set 13 | clifton
# Processing Record 3 of Set 13 | tynda
# Processing Record 4 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 13 | severnyy-kospashskiy
# Processing Record 6 of Set 13 | lander
# Processing Record 7 of Set 13 | sohag
# Processing Record 8 of Set 13 | micheweni
# Processing Record 9 of Set 13 | tommot
# Processing Record 10 of Set 13 | thinadhoo
# Processing Record 11 of Set 13 | chipinge
# Processing Record 12 of Set 13 | milton
# Processing Record 13 of Set 13 | tunduru
# City not found. Skipping...
# Processing Record 14 of Set 13 | pervomayskoye
# Processing Record 15 of Set 13 | pampa
# Processing Record 16 of Set 13 | maldonado
# Processing Record 17 of Set 13 | bulawayo
# Processing Record 18 of Set 13 | ciechocinek
# Processing Record 19 of Set 13 | bull savanna
# Processing Record 20 of Set 13 | hasaki
# Processing Record 21 of Set 13 | yuzhno-kurilsk
# Processing Record 22 of Set 13 | kahta
# Processing Record 23 of Set 13 | kentau
# Processing Record 24 of Set 13 | inuvik
# Processing Record 25 of Set 13 | yatou
# Processing Record 26 of Set 13 | maarianhamina
# Processing Record 27 of Set 13 | shaowu
# Processing Record 28 of Set 13 | qixingtai
# Processing Record 29 of Set 13 | channagiri
# Processing Record 30 of Set 13 | porto walter
# Processing Record 31 of Set 13 | dyakonovo
# City not found. Skipping...
# Processing Record 32 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 13 | troitsko-pechorsk
# Processing Record 34 of Set 13 | gizo
# Processing Record 35 of Set 13 | ust-koksa
# Processing Record 36 of Set 13 | mutare
# Processing Record 37 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 38 of Set 13 | alofi
# Processing Record 39 of Set 13 | komsomolskiy
# Processing Record 40 of Set 13 | iguape
# Processing Record 41 of Set 13 | anadyr
# Processing Record 42 of Set 13 | mamlyutka
# Processing Record 43 of Set 13 | evensk
# Processing Record 44 of Set 13 | moa
# Processing Record 45 of Set 13 | luderitz
# Processing Record 46 of Set 13 | meulaboh
# Processing Record 47 of Set 13 | llata
# Processing Record 48 of Set 13 | vila velha
# Processing Record 49 of Set 13 | cap malheureux
# Processing Record 50 of Set 13 | esna
# Processing Record 1 of Set 14 | vanimo
# Processing Record 2 of Set 14 | jalu
# Processing Record 3 of Set 14 | berwick
# Processing Record 4 of Set 14 | lukovetskiy
# Processing Record 5 of Set 14 | dubti
# Processing Record 6 of Set 14 | kidal
# Processing Record 7 of Set 14 | chatakonda
# Processing Record 8 of Set 14 | harnai
# Processing Record 9 of Set 14 | alihe
# Processing Record 10 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 11 of Set 14 | zhuanghe
# Processing Record 12 of Set 14 | ilulissat
# Processing Record 13 of Set 14 | bela
# Processing Record 14 of Set 14 | ponta delgada
# Processing Record 15 of Set 14 | aykhal
# Processing Record 16 of Set 14 | timra
# Processing Record 17 of Set 14 | indian head
# Processing Record 18 of Set 14 | barmer
# Processing Record 19 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 14 | taft
# Processing Record 21 of Set 14 | baie-saint-paul
# Processing Record 22 of Set 14 | mishan
# Processing Record 23 of Set 14 | waipawa
# Processing Record 24 of Set 14 | olsztyn
# Processing Record 25 of Set 14 | buala
# Processing Record 26 of Set 14 | cabedelo
# Processing Record 27 of Set 14 | barrhead
# Processing Record 28 of Set 14 | xai-xai
# Processing Record 29 of Set 14 | ahuimanu
# Processing Record 30 of Set 14 | san cristobal
# Processing Record 31 of Set 14 | xiuyan
# Processing Record 32 of Set 14 | ullapool
# Processing Record 33 of Set 14 | matamoros
# Processing Record 34 of Set 14 | ayagoz
# Processing Record 35 of Set 14 | sitges
# Processing Record 36 of Set 14 | zhangjiakou
# Processing Record 37 of Set 14 | majene
# Processing Record 38 of Set 14 | rovnoye
# Processing Record 39 of Set 14 | maragogi
# Processing Record 40 of Set 14 | alice springs
# Processing Record 41 of Set 14 | villa carlos paz
# Processing Record 42 of Set 14 | jhang
# Processing Record 43 of Set 14 | saldanha
# Processing Record 44 of Set 14 | comodoro rivadavia
# Processing Record 45 of Set 14 | tonstad
# Processing Record 46 of Set 14 | ambilobe
# Processing Record 47 of Set 14 | vatutinki
# Processing Record 48 of Set 14 | copiapo
# Processing Record 49 of Set 14 | safaga
# Processing Record 50 of Set 14 | marapanim
# Processing Record 1 of Set 15 | muriwai beach
# Processing Record 2 of Set 15 | atka
# City not found. Skipping...
# Processing Record 3 of Set 15 | narbonne
# Processing Record 4 of Set 15 | saint-pierre
# Processing Record 5 of Set 15 | carauari
# Processing Record 6 of Set 15 | dalby
# Processing Record 7 of Set 15 | rincon
# Processing Record 8 of Set 15 | spring valley
# Processing Record 9 of Set 15 | nokaneng
# Processing Record 10 of Set 15 | beian
# Processing Record 11 of Set 15 | christchurch
# Processing Record 12 of Set 15 | caibarien
# Processing Record 13 of Set 15 | tanout
# Processing Record 14 of Set 15 | van buren
# Processing Record 15 of Set 15 | yumen
# Processing Record 16 of Set 15 | silca
# Processing Record 17 of Set 15 | mgachi
# Processing Record 18 of Set 15 | belmonte
# Processing Record 19 of Set 15 | synya
# Processing Record 20 of Set 15 | davenda
# Processing Record 21 of Set 15 | makakilo city
# Processing Record 22 of Set 15 | hualmay
# Processing Record 23 of Set 15 | amahai
# Processing Record 24 of Set 15 | nguruka
# Processing Record 25 of Set 15 | pueblo
# Processing Record 26 of Set 15 | oxford
# Processing Record 27 of Set 15 | camargo
# Processing Record 28 of Set 15 | muscat
# Processing Record 29 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 31 of Set 15 | shingu
# Processing Record 32 of Set 15 | tezu
# Processing Record 33 of Set 15 | mathathane
# Processing Record 34 of Set 15 | kavaratti
# Processing Record 35 of Set 15 | aasiaat
# Processing Record 36 of Set 15 | sturgeon bay
# Processing Record 37 of Set 15 | cerrito
# Processing Record 38 of Set 15 | jacareacanga
# Processing Record 39 of Set 15 | coalcoman
# City not found. Skipping...
# Processing Record 40 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 15 | carballo
# Processing Record 42 of Set 15 | antofagasta
# Processing Record 43 of Set 15 | baghdogra
# Processing Record 44 of Set 15 | sakaiminato
# Processing Record 45 of Set 15 | emerald
# Processing Record 46 of Set 15 | camudmud
# Processing Record 47 of Set 15 | qui nhon
# Processing Record 48 of Set 15 | chifeng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 683

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Pisco      PE -13.7000  -76.2167     75.20        69
# 1  Vila Franca Do Campo      PT  37.7167  -25.4333     57.00        67
# 2                 Purpe      RU  64.4803   76.6897    -13.90        90
# 3       Arraial Do Cabo      BR -22.9661  -42.0278     86.00        74
# 4             Busselton      AU -33.6500  115.3333     59.00        75
# 5          Ponta Do Sol      PT  32.6667  -17.1000     52.00        66
# 6            Bredasdorp      ZA -34.5322   20.0403     68.00        83
# 7                Atuona      PF  -9.8000 -139.0333     79.52        80
# 8               Paamiut      GL  61.9940  -49.6678     21.07        78
# 9         Bambanglipuro      ID  -7.9500  110.2833     76.05        87
#
#    Cloudiness  Wind Speed Current Description
# 0           0       11.50           clear sky
# 1          40       11.50    scattered clouds
# 2         100        7.02     overcast clouds
# 3           0        8.05           clear sky
# 4         100        1.99     overcast clouds
# 5          28        3.00    scattered clouds
# 6          30        2.30    scattered clouds
# 7          11       16.80          few clouds
# 8           0        9.71           clear sky
# 9         100        3.58     overcast clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
